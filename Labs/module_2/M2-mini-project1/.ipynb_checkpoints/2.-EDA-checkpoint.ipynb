# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_data = r"C:\Users\jeanb\Desktop\Cours\Cours Ironhack\0323_2020DATAPAR\Labs\module_2\M2-mini-project1"

# %%
diamonds = pd.read_csv(path_data+'/diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    clarity_int  color_int
# 0            1          5
# 1            2          5
# 2            4          5
# 3            3          1
# 4            1          0

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe().T
# Out:
#                count         mean          std     min     25%      50%  \
# carat        53932.0     0.797879     0.473986    0.20    0.40     0.70
# depth        53932.0    61.749336     1.432514   43.00   61.00    61.80
# table        53932.0    57.457029     2.234064   43.00   56.00    57.00
# price        53932.0  3932.136079  3988.734835  326.00  949.75  2401.00
# x            53932.0     5.732007     1.119670    3.73    4.71     5.70
# y            53932.0     5.734141     1.113272    3.68    4.72     5.71
# z            53932.0     3.539735     0.692051    1.07    2.91     3.53
# clarity_int  53932.0     3.051101     1.647109    0.00    2.00     3.00
# color_int    53932.0     3.405789     1.701165    0.00    2.00     3.00
#
#                  75%       max
# carat           1.04      5.01
# depth          62.50     79.00
# table          59.00     95.00
# price        5324.00  18823.00
# x               6.54     10.74
# y               6.54     19.28
# z               4.04      8.06
# clarity_int     4.00      7.00
# color_int       5.00      6.00

# %%
#your comments here
# For many columns there is a quite big gap between the 75th quartile and the max
# such as for the carat, the table, the price, and x, y, z
# As we've seen before, for the price for example, there are a lot of outliers but that are continuous to the
# normal values ; cf boxplots

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here

# I would say the carat (weight), the clarity and the color

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
color_means = diamonds.groupby("color").agg("mean")
color_means
# Out:
#           carat      depth      table        price         x         y  \
# color
# D      0.657715  61.698066  57.404355  3168.106436  5.417851  5.421928
# E      0.657867  61.662090  57.491201  3076.752475  5.411580  5.416949
# F      0.736509  61.694087  57.433148  3725.091938  5.616727  5.620529
# G      0.771088  61.757449  57.288060  3998.145173  5.678549  5.681198
# H      0.911627  61.836557  57.518176  4484.958805  5.984776  5.981484
# I      1.026927  61.846385  57.577278  5091.874954  6.222826  6.222730
# J      1.162137  61.887215  57.812393  5323.818020  6.519338  6.518105
#
#               z  clarity_int  color_int
# color
# D      3.343320     2.691025        6.0
# E      3.337767     2.969889        5.0
# F      3.465938     3.134605        4.0
# G      3.507966     3.463419        3.0
# H      3.699147     2.933871        2.0
# I      3.846369     2.964035        1.0
# J      4.033251     2.776353        0.0

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here
# Surprisngly, the mean prices of diamonds seems to be lower the better the color is.

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
color_means.price.plot.bar(figsize = (6,5), color="orange")
plt.title("Diamonds mean price by colors")
# Out:
# Text(0.5, 1.0, 'Diamonds mean price by colors')

# %%
color_count = diamonds.groupby("color")["x"].agg("count")

color_count.plot.bar(figsize = (6,5))
plt.title("Frequency of colors")
# Out:
# Text(0.5, 1.0, 'Frequency of colors')

# %%
#your comments here
# As for the frequency distribution, the "middle" colors (E, F, G, H) are the most frequent
# which makes sense when looking at the mean of diamonds' price

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
carat_means = diamonds.groupby("carat").agg("mean")
carat_means
# Out:
#            depth      table         price          x          y         z  \
# carat
# 0.20   61.100000  59.333333    365.166667   3.786667   3.753333  2.303333
# 0.21   60.511111  58.444444    380.222222   3.874444   3.837778  2.332222
# 0.22   61.620000  60.400000    391.400000   3.898000   3.848000  2.386000
# 0.23   61.426621  58.034130    486.143345   3.946382   3.973379  2.431468
# 0.24   61.599213  57.488189    505.185039   3.990157   4.019331  2.465591
# ...          ...        ...           ...        ...        ...       ...
# 4.00   63.300000  58.000000  15984.000000  10.010000   9.940000  6.310000
# 4.01   61.750000  61.500000  15223.000000  10.080000  10.020000  6.205000
# 4.13   64.800000  61.000000  17329.000000  10.000000   9.850000  6.430000
# 4.50   65.800000  58.000000  18531.000000  10.230000  10.160000  6.720000
# 5.01   65.500000  59.000000  18018.000000  10.740000  10.540000  6.980000
#
#        clarity_int  color_int
# carat
# 0.20      2.833333   5.166667
# 0.21      2.666667   5.444444
# 0.22      2.600000   4.800000
# 0.23      4.901024   4.518771
# 0.24      4.972441   4.185039
# ...            ...        ...
# 4.00      0.000000   1.000000
# 4.01      0.000000   0.500000
# 4.13      0.000000   2.000000
# 4.50      0.000000   0.000000
# 5.01      0.000000   0.000000
#
# [273 rows x 8 columns]

# %%
carat_means.price.plot(figsize=(10,5), title="Diamonds price as a function of carat")

# %%
#your comments
# Here we can see that the price increases almost continuously with the carat, with a few exceptions of
# variations, but the trend is clear

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
#plt.hist(diamonds.carat, bins=50)
diamonds.carat.plot(kind="hist", bins=50, title="Histogram of carat values")

# %%
# We can see above that there are much more entries between 0 and 2 carat than between 2 and 5 ;
# these are much more rare values

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
table_means = diamonds.groupby("table").agg("mean")
table_means
# Out:
#         carat  depth    price      x      y      z  clarity_int  color_int
# table
# 43.0   1.0400  62.90   4997.0  6.450  6.410  4.040         4.00        1.0
# 44.0   0.2900  62.80    474.0  4.200  4.240  2.650         4.00        5.0
# 49.0   0.6500  64.25   2290.5  5.355  5.320  3.425         3.00        3.0
# 50.0   1.5100  61.50   8995.5  7.380  7.295  4.510         2.00        3.0
# 50.1   0.9400  66.00   3353.0  6.130  6.170  4.060         1.00        2.0
# ...       ...    ...      ...    ...    ...    ...          ...        ...
# 71.0   0.6800  58.00   1633.0  5.850  5.700  3.350         2.00        3.0
# 73.0   0.6025  68.90   2406.5  5.520  5.465  3.745         3.25        4.5
# 76.0   0.7900  65.30   2362.0  5.520  5.130  3.350         2.00        3.0
# 79.0   0.8100  68.80   2301.0  5.260  5.200  3.580         1.00        4.0
# 95.0   2.0100  58.60  13387.0  8.320  8.310  4.870         2.00        4.0
#
# [127 rows x 8 columns]

# %%
diamonds.table.plot(kind="hist", bins=50, title="Histogram of table values")

# %%
table_means.price.plot(figsize=(10,5), title="Diamonds price as a function of table")

# %%
#your comments here
# As we can see above, most table values are between 50 and 70, so it is difficult to really define
# a trend in the relation between table and price. The remaining outliers seems to have the highest price values

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
clarity_means = diamonds.groupby("clarity_int").agg("mean")
clarity_means
# Out:
#                 carat      depth      table        price         x         y  \
# clarity_int
# 0            1.283846  62.734278  58.303779  3924.168691  6.761093  6.709379
# 1            1.077602  61.771567  57.926823  5062.267356  6.404157  6.395579
# 2            0.850482  61.853042  57.662541  3996.001148  5.888383  5.888256
# 3            0.763850  61.724249  57.418040  3924.166204  5.658633  5.659782
# 4            0.727108  61.667968  57.313966  3839.144308  5.572860  5.580017
# 5            0.596202  61.663778  57.024990  3283.737071  5.218454  5.232118
# 6            0.503131  61.624521  56.883881  2519.512315  4.961721  4.976437
# 7            0.505123  61.510615  56.507207  2864.839106  4.968402  4.989827
#
#                     z  color_int
# clarity_int
# 0            4.224688   2.968961
# 1            3.952642   3.469967
# 2            3.640636   3.448450
# 3            3.492788   3.494370
# 4            3.437925   3.161812
# 5            3.221465   3.569483
# 6            3.062132   3.350848
# 7            3.061659   3.101676

# %%
clarity_means.price.plot.bar(figsize = (6,5), color="orange")
plt.title("Diamonds mean price by clarity")
# Out:
# Text(0.5, 1.0, 'Diamonds mean price by clarity')

# %%
clarity_count = diamonds.groupby("clarity_int")["x"].agg("count")

clarity_count.plot.bar(figsize = (6,5))
plt.title("Frequency of clarity")
# Out:
# Text(0.5, 1.0, 'Frequency of clarity')

# %%
#your comments here
# As for clarity, most values are within the 1 to 4 categories, or the "central" ones,
# and for price distribution with this attribute again it surprisingly decrease a bit with the best clarity types

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
# The attributes that determine the most the price seems to be carat, and the color but not as we could imagine ;
# for the first one it seems logical that the higher the carat is, the higher the price will be, but as for
# color it is the opposite of what we could have expected, since the price decreases as the color gets better

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
# Here we can see that it is indeed the carat that seems to be the most linked to the price, as the x,y,z values
# obviously since they are related to the size and structure, and so to the weight (carat in a sense).
# But as for our hypothesis on color and clarity, these seems pretty uncorrelated with the price attribute of
# diamonds, as their values on the matrix above is near 0.

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493658995804609

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
# Here the 0.84 means that carat is a feature that can explain pretty well the variability of the price feature.

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here
# Maybe taking a look at the type of cut of the diamonds could be interesting ?
# Since carat is the main way that diamonds are refered to when jewelry are selling them, it actually seems
# logical that it is the most influential feature for the price attribute.

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
